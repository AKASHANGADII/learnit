# %%
# !pip install gtts
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install playsound

from playsound import playsound
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from gtts import gTTS

import os

mytext ='Obrigado'

language = 'pt'


myobj = gTTS(text=mytext, lang=language, slow=False,tld='pt')


myobj.save("obrigado.mp3")

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import required module
from pydub import AudioSegment
from pydub.playback import play

# for playing mp3 file
song = AudioSegment.from_mp3("/content/welcome.mp3")
print('playing sound using pydub')
play(song)
# Out:
# playing sound using pydub

# %%
# !pip install SpeechRecognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "obrigado_api.mp3"
output_file = "obrigado_.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
# Out:
# ---------------------------------------------------------------------------
# CouldntDecodeError                        Traceback (most recent call last)
# <ipython-input-89-9801fdaa0f49> in <cell line: 10>()
#       8
#       9 # convert mp3 file to wav file
# ---> 10 sound = AudioSegment.from_mp3(input_file)
#      11 sound.export(output_file, format="wav")
#
# /usr/local/lib/python3.9/dist-packages/pydub/audio_segment.py in from_mp3(cls, file, parameters)
#     794     @classmethod
#     795     def from_mp3(cls, file, parameters=None):
# --> 796         return cls.from_file(file, 'mp3', parameters=parameters)
#     797
#     798     @classmethod
#
# /usr/local/lib/python3.9/dist-packages/pydub/audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     771             if close_file:
#     772                 file.close()
# --> 773             raise CouldntDecodeError(
# ...

# %%
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile

# sample_rate, samples = wavfile.read('/content/result_test.wav')
# frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

# plt.pcolormesh(times, frequencies, spectrogram)
# plt.imshow(spectrogram)
# plt.ylabel('Frequency [Hz]')
# plt.xlabel('Time [sec]')
# plt.show()

# %%
Fs, aud = wavfile.read('/content/result_test.wav')
# select left channel only
# aud = aud[:,0]
powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(aud, Fs=Fs)
plt.show()
plt.savefig('my_plot.png')

# %%
plt.savefig('my_plot.jpg')

# %%
import cv2
import numpy as np;
 
# Read image
im = cv2.imread("", cv2.IMREAD_GRAYSCALE)
 
# Set up the detector with default parameters.
detector = cv2.SimpleBlobDetector()
 
# Detect blobs.
keypoints = detector.detect(im)
 
# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
im_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
 
# Show keypoints
cv2.imshow("Keypoints", im_with_keypoints)
cv2.waitKey(0)

# %%
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install dtw-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.1/648.1 kB 27.1 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall dtw
# Out:
# Found existing installation: dtw 1.4.0
# Uninstalling dtw-1.4.0:
#   Would remove:
#     /usr/local/lib/python3.9/dist-packages/dtw-1.4.0.dist-info/*
#     /usr/local/lib/python3.9/dist-packages/dtw/*
#     /usr/local/lib/python3.9/dist-packages/tests/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.9/dist-packages/dtw/__main__.py
#     /usr/local/lib/python3.9/dist-packages/dtw/_backtrack.py
#     /usr/local/lib/python3.9/dist-packages/dtw/_dtw_utils.c
#     /usr/local/lib/python3.9/dist-packages/dtw/_dtw_utils.cpython-39-x86_64-linux-gnu.so
#     /usr/local/lib/python3.9/dist-packages/dtw/_dtw_utils.pyx
#     /usr/local/lib/python3.9/dist-packages/dtw/_globalCostMatrix.py
#     /usr/local/lib/python3.9/dist-packages/dtw/countPaths.py
#     /usr/local/lib/python3.9/dist-packages/dtw/data/README.txt
#     /usr/local/lib/python3.9/dist-packages/dtw/data/aami3a.csv
#     /usr/local/lib/python3.9/dist-packages/dtw/data/aami3b.csv
# ...

# %%
# !pip uninstall dtw_python
# Out:
# Found existing installation: dtw-python 1.3.0
# Uninstalling dtw-python-1.3.0:
#   Would remove:
#     /usr/local/bin/dtw
#     /usr/local/lib/python3.9/dist-packages/dtw/__main__.py
#     /usr/local/lib/python3.9/dist-packages/dtw/_backtrack.py
#     /usr/local/lib/python3.9/dist-packages/dtw/_dtw_utils.c
#     /usr/local/lib/python3.9/dist-packages/dtw/_dtw_utils.cpython-39-x86_64-linux-gnu.so
#     /usr/local/lib/python3.9/dist-packages/dtw/_dtw_utils.pyx
#     /usr/local/lib/python3.9/dist-packages/dtw/_globalCostMatrix.py
#     /usr/local/lib/python3.9/dist-packages/dtw/countPaths.py
#     /usr/local/lib/python3.9/dist-packages/dtw/data/README.txt
#     /usr/local/lib/python3.9/dist-packages/dtw/data/aami3a.csv
#     /usr/local/lib/python3.9/dist-packages/dtw/data/aami3b.csv
#     /usr/local/lib/python3.9/dist-packages/dtw/dtwPlot.py
#     /usr/local/lib/python3.9/dist-packages/dtw/dtw_core.c
#     /usr/local/lib/python3.9/dist-packages/dtw/dtw_core.h
# ...

# %%
import librosa
import matplotlib.pyplot as plt
from dtw import dtw


#Loading audio files
y1, sr1 = librosa.load('/content/newObrigadoAbhi.wav') 
y2, sr2 = librosa.load('/content/newObrigadoAbhi.wav') 

#Showing multiple plots using subplot
plt.subplot(1, 2, 1) 
mfcc1 = librosa.feature.mfcc(y=y1,sr=sr1)   #Computing MFCC values
librosa.display.specshow(mfcc1)

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y=y2,sr= sr2)
librosa.display.specshow(mfcc2)

from numpy.linalg import norm
dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print ('Normalized distance between the two sounds:', dist)
      

plt.imshow(cost.T, origin='lower', cmap=plt.get_cmap('gray'), interpolation='nearest')
plt.plot(path[0], path[1], 'w')   #creating plot for DTW

plt.show()  #To display the plots graphically
# Out:
# Normalized distance between the two sounds: 0.0
